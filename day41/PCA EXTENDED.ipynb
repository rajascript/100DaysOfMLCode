# %%
from sklearn.datasets import make_circles

# %%
from sklearn.decomposition import PCA, KernelPCA

# %%
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# /Users/Th3D4rKnight/anaconda3/envs/aarus_project/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
np.random.seed(0)

# %%
X, y = make_circles(n_samples=400,factor=0.3,noise=0.05)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(X[:,0],X[:,1])

# %%
kpca  = KernelPCA(kernel='rbf', gamma=10, fit_inverse_transform=True)
x_kpca = kpca.fit_transform(X)
x_back = kpca.inverse_transform(x_kpca)

# %%
pca = PCA()

# %%
X_pca = pca.fit_transform(X);

# %%
plt.title("original")
red = y == 0
blue = y == 1

plt.scatter(X[red,0],X[red,1],c="red",s=20,edgecolor="k")
plt.scatter(X[blue,0],X[blue,1],c="blue",s=20,edgecolor="k")

# %%
plt.scatter(X_pca[red,0],X[red,1],c="red",s=20,edgecolor="k")
plt.scatter(X_pca[blue,0],X[blue,1],c="blue",s=20,edgecolor="k")

# %%
plt.scatter(x_kpca[red,0],X[red,1],c="red",s=20,edgecolor="k")
plt.scatter(x_kpca[blue,0],X[blue,1],c="blue",s=20,edgecolor="k")

# %%
df = sns.load_dataset('iris')

# %%
col = ['petal_length','petal_width']
X = df.loc[:, col]

# %%
species_to_num = {'versicolor': 0,
                  'setosa': 2,
                  'virginica': 1}

# %%
df['tmp']= df['species'].map(species_to_num)

# %%
y = df['tmp']
y
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
# 5      2
# 6      2
# 7      2
# 8      2
# 9      2
# 10     2
# 11     2
# 12     2
# 13     2
# 14     2
# 15     2
# 16     2
# 17     2
# 18     2
# 19     2
# 20     2
# 21     2
# 22     2
# 23     2
# 24     2
# 25     2
# 26     2
# 27     2
# 28     2
# 29     2
#       ..
# 120    1
# 121    1
# 122    1
# 123    1
# 124    1
# 125    1
# 126    1
# 127    1
# 128    1
# 129    1
# 130    1
# 131    1
# 132    1
# 133    1
# 134    1
# 135    1
# 136    1
# 137    1
# 138    1
# 139    1
# 140    1
# 141    1
# 142    1
# 143    1
# 144    1
# 145    1
# 146    1
# 147    1
# 148    1
# 149    1
# Name: tmp, Length: 150, dtype: int64

# %%
kpca = KernelPCA(kernel='rbf',n_components=2)

# %%
X_kpca = kpca.fit_transform(X)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
clf.fit(X_kpca, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

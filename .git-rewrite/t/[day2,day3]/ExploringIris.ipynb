# %% [markdown]
# # 100DaysOfMLCode
# ## Day 2 & Day 3

# %%
import sys; sys.path
# Out:
# ['',
#  '/Users/Th3D4rKnight/anaconda3/envs/aarus_project/lib/python36.zip',
#  '/Users/Th3D4rKnight/anaconda3/envs/aarus_project/lib/python3.6',
#  '/Users/Th3D4rKnight/anaconda3/envs/aarus_project/lib/python3.6/lib-dynload',
#  '/Users/Th3D4rKnight/anaconda3/envs/aarus_project/lib/python3.6/site-packages',
#  '/Users/Th3D4rKnight/anaconda3/envs/aarus_project/lib/python3.6/site-packages/aeosa',
#  '/Users/Th3D4rKnight/anaconda3/envs/aarus_project/lib/python3.6/site-packages/IPython/extensions',
#  '/Users/Th3D4rKnight/.ipython']

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
df = pd.read_csv("iris.data",header=-1);

# %%
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
col_name = ['sepal_length','sepal width', 'petal length', 'petal width', 'class']

# %%
df.columns = col_name

# %%
df.head()
# Out:
#    sepal_length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
 iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
 iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# None

# %%
print(iris.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# ## Visualisation

# %%
sns.pairplot(iris, hue='species', size=3, aspect=1);
plt.show()

# %%
iris.hist(edgecolor="black", linewidth=1, figsize=(10,10))
plt.show()

# %% [markdown]
# # Supervised Learning: Simple Linear Regression

# %%
x = 10 * np.random.rand(100)

# %%
y = 1 * x + np.random.rand(100)

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)

# %%
X=x.reshape(-1,1)

# %%
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.coef_
# Out:
# array([100.00658992])

# %%
model.intercept_
# Out:
# 0.4497480179197737

# %%
x_fit = np.linspace(-1, 11)
x_fit
# Out:
# array([-1.        , -0.75510204, -0.51020408, -0.26530612, -0.02040816,
#         0.2244898 ,  0.46938776,  0.71428571,  0.95918367,  1.20408163,
#         1.44897959,  1.69387755,  1.93877551,  2.18367347,  2.42857143,
#         2.67346939,  2.91836735,  3.16326531,  3.40816327,  3.65306122,
#         3.89795918,  4.14285714,  4.3877551 ,  4.63265306,  4.87755102,
#         5.12244898,  5.36734694,  5.6122449 ,  5.85714286,  6.10204082,
#         6.34693878,  6.59183673,  6.83673469,  7.08163265,  7.32653061,
#         7.57142857,  7.81632653,  8.06122449,  8.30612245,  8.55102041,
#         8.79591837,  9.04081633,  9.28571429,  9.53061224,  9.7755102 ,
#        10.02040816, 10.26530612, 10.51020408, 10.75510204, 11.        ])

# %%
X_fit = x_fit.reshape(-1,1)

# %%
y_fit = model.predict(X_fit)
y_fit
# Out:
# array([ -99.5568419 ,  -75.06543213,  -50.57402235,  -26.08261257,
#          -1.5912028 ,   22.90020698,   47.39161676,   71.88302653,
#          96.37443631,  120.86584608,  145.35725586,  169.84866564,
#         194.34007541,  218.83148519,  243.32289497,  267.81430474,
#         292.30571452,  316.79712429,  341.28853407,  365.77994385,
#         390.27135362,  414.7627634 ,  439.25417318,  463.74558295,
#         488.23699273,  512.72840251,  537.21981228,  561.71122206,
#         586.20263183,  610.69404161,  635.18545139,  659.67686116,
#         684.16827094,  708.65968072,  733.15109049,  757.64250027,
#         782.13391004,  806.62531982,  831.1167296 ,  855.60813937,
#         880.09954915,  904.59095893,  929.0823687 ,  953.57377848,
#         978.06518825, 1002.55659803, 1027.04800781, 1051.53941758,
#        1076.03082736, 1100.52223714])

# %%
plt.scatter(x,y)
plt.scatter(x_fit,y_fit)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
sns.set()

# %%
rand_num = np.random.RandomState(42)

# %%
X = np.dot(rand_num.rand(2,2), rand_num.randn(2, 5000)).T
X
# Out:
# array([[ 0.60901126,  0.2673155 ],
#        [-1.29912439, -0.9342167 ],
#        [ 1.58828601,  1.78365725],
#        ...,
#        [-0.46026448, -0.51478623],
#        [-1.24047913, -1.67202716],
#        [-0.018656  , -0.17552132]])

# %%
X[:, 0] = - X[:, 0]

# %%
plt.scatter(X[:, 0], X[:, 1]);
plt.axis('equal')
# Out:
# (-3.7373887150600615, 4.389544605796352, -4.061849240158013, 3.749186986809209)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1)
pca.fit(X)
X_pca = pca.transform(X)

# %%
X_pca.shape
# Out:
# (5000, 1)

# %%
X_new  = pca.inverse_transform(X_pca)
plt.scatter(X[:, 0], X[:, 1],alpha=0.2)
plt.scatter(X_new[:, 0], X_new[:, 1],alpha=0.8)
plt.axis('equal')
# Out:
# (-3.7373887150600615, 4.389544605796352, -4.061849240158013, 3.749186986809209)
